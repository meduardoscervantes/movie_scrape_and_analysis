# %%
import pandas as pd
import requests
import json
import numpy as np

# %%
df = pd.read_csv("resources/hbo_movies.csv")
df.head()
# Out:
#                      name                                        description
# 0    (500) Days of Summer  A romance between two young office employees i...
# 1  1, 2, 3 All Eyes on Me  A loving fourth-grade teacher gets caught in a...
# 2             10,000 B.C.  Experience the prehistoric past in this stunni...
# 3               12 Rounds  New Orleans cop John Cena must undergo a dozen...
# 4   12 Rounds 2: Reloaded  A hardworking EMT becomes a pawn in a criminal...

# %%
query_url = "http://www.omdbapi.com/?apikey=7c744b18&"
query_url
# Out:
# 'http://www.omdbapi.com/?apikey=7c744b18&'

# %%
data = [requests.get(query_url + f"t={x}&type=movie&plot=full").json() for x in df['name'].tolist()]
data[:4]
# Out:
# [{'Title': 'Not a Love Story: Making (500) Days of Summer',
#   'Year': '2009',
#   'Rated': 'Not Rated',
#   'Released': '22 Dec 2009',
#   'Runtime': '30 min',
#   'Genre': 'Documentary, Short',
#   'Director': 'Charles de Lauzirika',
#   'Writer': 'N/A',
#   'Actors': 'Zooey Deschanel, Joseph Gordon-Levitt, Scott Neustadter, Marc Webb',
#   'Plot': "A behind-the-scenes documentary exploring the making of Marc Webb's 500 Days of Summer (2009).",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.7',
#   'imdbVotes': '43',
#   'imdbID': 'tt1572162',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': '1, 2, 3, All Eyes on Me',
#   'Year': '2020',
#   'Rated': 'N/A',
#   'Released': '12 Mar 2020',
#   'Runtime': '15 min',
#   'Genre': 'Short, Drama',
#   'Director': 'Emil Gallardo',
#   'Writer': 'Emil Gallardo, Derek Ho',
#   'Actors': 'Farelle Walker, Blanca Ordaz, Armand Munoz',
#   'Plot': 'When a crisis suddenly engulfs an elementary school campus, a determined art teacher tries everything she can to save her class.',
#   'Language': 'English',
#   'Country': 'N/A',
#   'Awards': '17 wins & 2 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYTVkYTdjZGQtZjBiNi00N2E3LTllM2EtZTY1ZjI0MmU3ZmNjXkEyXkFqcGdeQXVyNjc4NTEwMTg@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.6',
#   'imdbVotes': '159',
#   'imdbID': 'tt11724300',
#   'Type': 'movie',
#   'DVD': '23 Apr 2021',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': '10,000 BC',
#   'Year': '2008',
#   'Rated': 'PG-13',
#   'Released': '07 Mar 2008',
#   'Runtime': '109 min',
#   'Genre': 'Action, Adventure, Drama',
#   'Director': 'Roland Emmerich',
#   'Writer': 'Roland Emmerich, Harald Kloser',
#   'Actors': 'Camilla Belle, Steven Strait, Marco Khan',
#   'Plot': "A pseudo-orphaned semi-outcast since his father left his mammoth hunting tribe on a secret, prophecy-related mission, D'Leh grows up as protégé of master hunter Tic'Tic. Putting truth first, he sacrifices his cheater chance to win status and the charmed girl Evolet, who thus falls to his rival-buddy Ka'Ren. The couple is among the captives taken by horse-riding slave-hunters, but D'Leh takes charge of an epic rescue mission that follows the caravan all the way to the pyramid building site of a 'living god'. By winning the support of a people he impressed on the way thanks to a saber-tooth he once saved and secretly forging a slave rise, he bids for his people's liberation.",
#   'Language': 'English',
#   'Country': 'United States, South Africa',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzc2NDMzNDY4Ml5BMl5BanBnXkFtZTYwNzM2Njk3._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '9%'},
#    {'Source': 'Metacritic', 'Value': '34/100'}],
#   'Metascore': '34',
#   'imdbRating': '5.1',
#   'imdbVotes': '131,813',
#   'imdbID': 'tt0443649',
#   'Type': 'movie',
#   'DVD': '24 Jun 2008',
#   'BoxOffice': '$94,784,201',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': '12 Rounds',
#   'Year': '2009',
#   'Rated': 'PG-13',
#   'Released': '27 Mar 2009',
#   'Runtime': '108 min',
#   'Genre': 'Action, Crime, Thriller',
#   'Director': 'Renny Harlin',
#   'Writer': 'Daniel Kunka',
#   'Actors': 'John Cena, Ashley Scott, Aidan Gillen',
#   'Plot': "Uniformed New Orleans PD officer Danny Fisher earns his promotion to detective to his near-rather lucky, albeit brave, arrest of ruthless terrorist arms-dealer Miles Jackson, whose girlfriend Erica Kessen got accidentally killed during the dirty FBI-operation. Exactly a year later, Miles has escaped and blows up Danny's house as foretaste of a Herculean race to accomplish twelve near-impossible tasks against the clock, otherwise his kidnapped girlfriend Molly will be killed. Yet at the end, another master-plan is suspected.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU1MzM1ODkxM15BMl5BanBnXkFtZTcwNDY1MTA0Mg@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '31%'},
#    {'Source': 'Metacritic', 'Value': '38/100'}],
#   'Metascore': '38',
#   'imdbRating': '5.6',
#   'imdbVotes': '29,279',
#   'imdbID': 'tt1160368',
#   'Type': 'movie',
#   'DVD': '30 Jun 2009',
#   'BoxOffice': '$12,234,694',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'}]

# %%
print(json.dumps(data[0], indent=4))
# Out:
# {
#     "Title": "Not a Love Story: Making (500) Days of Summer",
#     "Year": "2009",
#     "Rated": "Not Rated",
#     "Released": "22 Dec 2009",
#     "Runtime": "30 min",
#     "Genre": "Documentary, Short",
#     "Director": "Charles de Lauzirika",
#     "Writer": "N/A",
#     "Actors": "Zooey Deschanel, Joseph Gordon-Levitt, Scott Neustadter, Marc Webb",
#     "Plot": "A behind-the-scenes documentary exploring the making of Marc Webb's 500 Days of Summer (2009).",
#     "Language": "English",
#     "Country": "USA",
#     "Awards": "N/A",
#     "Poster": "N/A",
#     "Ratings": [
#         {
#             "Source": "Internet Movie Database",
#             "Value": "7.7/10"
#         }
#     ],
#     "Metascore": "N/A",
#     "imdbRating": "7.7",
#     "imdbVotes": "43",
#     "imdbID": "tt1572162",
#     "Type": "movie",
#     "DVD": "N/A",
#     "BoxOffice": "N/A",
#     "Production": "N/A",
#     "Website": "N/A",
#     "Response": "True"
# }

# %%
class OmdbObj():
    def __init__(self):
        self.title = np.nan
        self.year = np.nan
        self.rated = np.nan
        self.released = np.nan
        self.runtime = np.nan
        self.genre = np.nan
        self.director = np.nan
        self.writer = np.nan
        self.actors = np.nan
        self.plot = np.nan
        self.language = np.nan
        self.country = np.nan
        self.awards = np.nan
        self.poster = np.nan
        self.ratings = np.nan
        self.metascore = np.nan
        self.imdbrating = np.nan
        self.imdbvotes = np.nan
        self.imdbid = np.nan
        self.type = np.nan
        self.dvd = np.nan
        self.boxoffice = np.nan
        self.production = np.nan
        self.website = np.nan
        self.response = np.nan
    
    def _get_dict(self):
        return {x: getattr(self, x) for x in dir(self) if "_" not in x}

# %%
def get_dict_item(val: dict):
    temp_obj = OmdbObj()
    for k,v in val.items():
        try:
            if type(v) is not dict and val['Response'] == "True" and val['Type'] == 'movie' and not v == 'N/A':
                setattr(temp_obj, k.lower(), v)
        except KeyError:
            continue
    return temp_obj._get_dict()

# %%
data_list_as_dict = [get_dict_item(x) for x in data]
for x in data_list_as_dict:
    if not len(x.keys()) == 25:
        print(x)
        print(x.keys)

# %%
omdb_df = pd.DataFrame()
for x in data_list_as_dict:
    omdb_df = omdb_df.append(x, ignore_index=True)
omdb_df.to_csv('resources/omdb_data.csv', index=False)
omdb_df.head()
# Out:
#                                               actors                   awards  \
# 0  Zooey Deschanel, Joseph Gordon-Levitt, Scott N...                      NaN
# 1         Farelle Walker, Blanca Ordaz, Armand Munoz  17 wins & 2 nominations
# 2           Camilla Belle, Steven Strait, Marco Khan                      NaN
# 3              John Cena, Ashley Scott, Aidan Gillen                      NaN
# 4          Randy Orton, Tom Stevens, Brian Markinson                      NaN
#
#      boxoffice                      country              director  \
# 0          NaN                          USA  Charles de Lauzirika
# 1          NaN                          NaN         Emil Gallardo
# 2  $94,784,201  United States, South Africa       Roland Emmerich
# 3  $12,234,694                United States          Renny Harlin
# 4          NaN                United States            Roel Reiné
#
#            dvd                        genre      imdbid imdbrating imdbvotes  \
# 0          NaN           Documentary, Short   tt1572162        7.7        43
# 1  23 Apr 2021                 Short, Drama  tt11724300        7.6       159
# 2  24 Jun 2008     Action, Adventure, Drama   tt0443649        5.1   131,813
# 3  30 Jun 2009      Action, Crime, Thriller   tt1160368        5.6    29,279
# 4  04 Jun 2013  Action, Adventure, Thriller   tt2317524        5.3     5,720
#
#    ...      rated                                            ratings  \
# 0  ...  Not Rated  [{'Source': 'Internet Movie Database', 'Value'...
# 1  ...        NaN  [{'Source': 'Internet Movie Database', 'Value'...
# 2  ...      PG-13  [{'Source': 'Internet Movie Database', 'Value'...
# 3  ...      PG-13  [{'Source': 'Internet Movie Database', 'Value'...
# 4  ...          R  [{'Source': 'Internet Movie Database', 'Value'...
#
#       released response  runtime  \
# 0  22 Dec 2009     True   30 min
# 1  12 Mar 2020     True   15 min
# 2  07 Mar 2008     True  109 min
# 3  27 Mar 2009     True  108 min
# 4  04 Jun 2013     True   95 min
#
#                                            title   type website  \
# 0  Not a Love Story: Making (500) Days of Summer  movie     NaN
# 1                        1, 2, 3, All Eyes on Me  movie     NaN
# 2                                      10,000 BC  movie     NaN
# 3                                      12 Rounds  movie     NaN
# 4                          12 Rounds 2: Reloaded  movie     NaN
#
#                            writer  year
# 0                             NaN  2009
# 1         Emil Gallardo, Derek Ho  2020
# 2  Roland Emmerich, Harald Kloser  2008
# 3                    Daniel Kunka  2009
# 4                   David Benullo  2013
#
# [5 rows x 25 columns]

# %%
final_df = pd.concat([df, omdb_df], axis=1, join='inner')
final_df
# Out:
#                                     name  \
# 0                   (500) Days of Summer
# 1                 1, 2, 3 All Eyes on Me
# 2                            10,000 B.C.
# 3                              12 Rounds
# 4                  12 Rounds 2: Reloaded
# ...                                  ...
# 1438                                 Yun
# 1439  Yusuf Hawkins: Storm Over Brooklyn
# 1440            Yvonne Orji: A Whole Me.
# 1441      Yvonne Orji: Momma, I Made It!
# 1442                                Zoom
#
#                                             description  \
# 0     A romance between two young office employees i...
# 1     A loving fourth-grade teacher gets caught in a...
# 2     Experience the prehistoric past in this stunni...
# 3     New Orleans cop John Cena must undergo a dozen...
# 4     A hardworking EMT becomes a pawn in a criminal...
# ...                                                 ...
# 1438  A young girl of Korean ancestry is told to spe...
# 1439  This film revisits the tragic 1989 death of an...
# 1440  Emmy® nominee Yvonne Orji uses therapy to disc...
# 1441  Comedian and actress Yvonne Orji (HBO's "Insec...
# 1442  An aging former superhero must assemble and tr...
#
#                                                  actors  \
# 0     Zooey Deschanel, Joseph Gordon-Levitt, Scott N...
# 1            Farelle Walker, Blanca Ordaz, Armand Munoz
# 2              Camilla Belle, Steven Strait, Marco Khan
# 3                 John Cena, Ashley Scott, Aidan Gillen
# 4             Randy Orton, Tom Stevens, Brian Markinson
# ...                                                 ...
# 1438                                                NaN
# 1439                                                NaN
# 1440                                                NaN
# 1441                                                NaN
# 1442                                                NaN
#
#                        awards    boxoffice                      country  \
# 0                         NaN          NaN                          USA
# 1     17 wins & 2 nominations          NaN                          NaN
# 2                         NaN  $94,784,201  United States, South Africa
# 3                         NaN  $12,234,694                United States
# 4                         NaN          NaN                United States
# ...                       ...          ...                          ...
# 1438                      NaN          NaN                          NaN
# 1439                      NaN          NaN                          NaN
# 1440                      NaN          NaN                          NaN
# 1441                      NaN          NaN                          NaN
# 1442                      NaN          NaN                          NaN
#
#                   director          dvd                        genre  \
# 0     Charles de Lauzirika          NaN           Documentary, Short
# 1            Emil Gallardo  23 Apr 2021                 Short, Drama
# 2          Roland Emmerich  24 Jun 2008     Action, Adventure, Drama
# 3             Renny Harlin  30 Jun 2009      Action, Crime, Thriller
# 4               Roel Reiné  04 Jun 2013  Action, Adventure, Thriller
# ...                    ...          ...                          ...
# 1438                   NaN          NaN                          NaN
# 1439                   NaN          NaN                          NaN
# 1440                   NaN          NaN                          NaN
# 1441                   NaN          NaN                          NaN
# 1442                   NaN          NaN                          NaN
#
#           imdbid  ...      rated  \
# 0      tt1572162  ...  Not Rated
# 1     tt11724300  ...        NaN
# 2      tt0443649  ...      PG-13
# 3      tt1160368  ...      PG-13
# 4      tt2317524  ...          R
# ...          ...  ...        ...
# 1438         NaN  ...        NaN
# 1439         NaN  ...        NaN
# 1440         NaN  ...        NaN
# 1441         NaN  ...        NaN
# 1442         NaN  ...        NaN
#
#                                                 ratings     released response  \
# 0     [{'Source': 'Internet Movie Database', 'Value'...  22 Dec 2009     True
# 1     [{'Source': 'Internet Movie Database', 'Value'...  12 Mar 2020     True
# 2     [{'Source': 'Internet Movie Database', 'Value'...  07 Mar 2008     True
# 3     [{'Source': 'Internet Movie Database', 'Value'...  27 Mar 2009     True
# 4     [{'Source': 'Internet Movie Database', 'Value'...  04 Jun 2013     True
# ...                                                 ...          ...      ...
# 1438                                                NaN          NaN      NaN
# 1439                                                NaN          NaN      NaN
# 1440                                                NaN          NaN      NaN
# 1441                                                NaN          NaN      NaN
# 1442                                                NaN          NaN      NaN
#
#       runtime                                          title   type website  \
# 0      30 min  Not a Love Story: Making (500) Days of Summer  movie     NaN
# 1      15 min                        1, 2, 3, All Eyes on Me  movie     NaN
# 2     109 min                                      10,000 BC  movie     NaN
# 3     108 min                                      12 Rounds  movie     NaN
# 4      95 min                          12 Rounds 2: Reloaded  movie     NaN
# ...       ...                                            ...    ...     ...
# 1438      NaN                                            NaN    NaN     NaN
# 1439      NaN                                            NaN    NaN     NaN
# 1440      NaN                                            NaN    NaN     NaN
# 1441      NaN                                            NaN    NaN     NaN
# 1442      NaN                                            NaN    NaN     NaN
#
#                               writer  year
# 0                                NaN  2009
# 1            Emil Gallardo, Derek Ho  2020
# 2     Roland Emmerich, Harald Kloser  2008
# 3                       Daniel Kunka  2009
# 4                      David Benullo  2013
# ...                              ...   ...
# 1438                             NaN   NaN
# 1439                             NaN   NaN
# 1440                             NaN   NaN
# 1441                             NaN   NaN
# 1442                             NaN   NaN
#
# [1443 rows x 27 columns]

# %%
final_df.to_csv('resources/final_data.csv', index=False)
