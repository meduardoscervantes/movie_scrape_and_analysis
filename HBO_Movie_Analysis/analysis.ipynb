# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv('resources/final_data.csv')
df.head()
# Out:
#                      name                                        description  \
# 0    (500) Days of Summer  A romance between two young office employees i...
# 1  1, 2, 3 All Eyes on Me  A loving fourth-grade teacher gets caught in a...
# 2             10,000 B.C.  Experience the prehistoric past in this stunni...
# 3               12 Rounds  New Orleans cop John Cena must undergo a dozen...
# 4   12 Rounds 2: Reloaded  A hardworking EMT becomes a pawn in a criminal...
#
#                                               actors                   awards  \
# 0  Zooey Deschanel, Joseph Gordon-Levitt, Scott N...                      NaN
# 1         Farelle Walker, Blanca Ordaz, Armand Munoz  17 wins & 2 nominations
# 2           Camilla Belle, Steven Strait, Marco Khan                      NaN
# 3              John Cena, Ashley Scott, Aidan Gillen                      NaN
# 4          Randy Orton, Tom Stevens, Brian Markinson                      NaN
#
#      boxoffice                      country              director  \
# 0          NaN                          USA  Charles de Lauzirika
# 1          NaN                          NaN         Emil Gallardo
# 2  $94,784,201  United States, South Africa       Roland Emmerich
# 3  $12,234,694                United States          Renny Harlin
# 4          NaN                United States            Roel Reiné
#
#            dvd                        genre      imdbid  ...      rated  \
# 0          NaN           Documentary, Short   tt1572162  ...  Not Rated
# 1  23 Apr 2021                 Short, Drama  tt11724300  ...        NaN
# 2  24 Jun 2008     Action, Adventure, Drama   tt0443649  ...      PG-13
# 3  30 Jun 2009      Action, Crime, Thriller   tt1160368  ...      PG-13
# 4  04 Jun 2013  Action, Adventure, Thriller   tt2317524  ...          R
#
#                                              ratings     released  response  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...  22 Dec 2009      True
# 1  [{'Source': 'Internet Movie Database', 'Value'...  12 Mar 2020      True
# 2  [{'Source': 'Internet Movie Database', 'Value'...  07 Mar 2008      True
# 3  [{'Source': 'Internet Movie Database', 'Value'...  27 Mar 2009      True
# 4  [{'Source': 'Internet Movie Database', 'Value'...  04 Jun 2013      True
#
#    runtime                                          title   type website  \
# 0   30 min  Not a Love Story: Making (500) Days of Summer  movie     NaN
# 1   15 min                        1, 2, 3, All Eyes on Me  movie     NaN
# 2  109 min                                      10,000 BC  movie     NaN
# 3  108 min                                      12 Rounds  movie     NaN
# 4   95 min                          12 Rounds 2: Reloaded  movie     NaN
#
#                            writer    year
# 0                             NaN  2009.0
# 1         Emil Gallardo, Derek Ho  2020.0
# 2  Roland Emmerich, Harald Kloser  2008.0
# 3                    Daniel Kunka  2009.0
# 4                   David Benullo  2013.0
#
# [5 rows x 27 columns]

# %%
df.iloc[random.randint(0,len(df))]
# Out:
# name                                           Mondays at Racine
# description    Two Long Island sisters use their beauty salon...
# actors           Rachel Delmolfetto, Linda Hart, Cambria Russell
# awards         Nominated for 1 Oscar. 5 wins & 2 nominations ...
# boxoffice                                                    NaN
# country                                            United States
# director                                            Cynthia Wade
# dvd                                                          NaN
# genre                                 Documentary, Short, Family
# imdbid                                                 tt2083264
# imdbrating                                                   7.4
# imdbvotes                                                    266
# language                                                 English
# metascore                                                    NaN
# plot           Every third Monday of the month, two bold, bra...
# poster         https://m.media-amazon.com/images/M/MV5BNzM4NT...
# production                                                   NaN
# rated                                                  Not Rated
# ratings        [{'Source': 'Internet Movie Database', 'Value'...
# released                                             20 Apr 2012
# response                                                    True
# runtime                                                   39 min
# title                                          Mondays at Racine
# type                                                       movie
# website                                                      NaN
# writer                                                       NaN
# year                                                      2012.0
# Name: 782, dtype: object

# %%
actors = []
for x in df['actors'].tolist():
    if not x == np.nan:
        for y in str(x).split(','):
            if y not in actors:
                tActor = y
                if y[0] == " ":
                    tActor = y[1:]
                if y[-1] == " ":
                    tActor = y[:-1]
                actors.append(tActor)

# %%
len(actors)
# Out:
# 2115

# %%
actors[:5]
# Out:
# ['Zooey Deschanel',
#  'Joseph Gordon-Levitt',
#  'Scott Neustadter',
#  'Marc Webb',
#  'Farelle Walker']

# %%
df_copy = df.fillna("N/A").copy()
actor_counts = [len(df_copy[df_copy['actors'].str.contains(x)]) for x in actors]
actor_counts[:5]
# Out:
# [1, 2, 1, 1, 1]

# %%
actor_df = pd.DataFrame(
    {
        'actor': actors,
        'movie_counts': actor_counts
    }
).drop_duplicates()
actor_df.sort_values(by='movie_counts', ascending=False).head(100)
# Out:
#                     actor  movie_counts
# 1488               Robert            46
# 810                  Matt            21
# 1144         Rupert Grint            10
# 1143     Daniel Radcliffe            10
# 811              Michelle            10
# ...                   ...           ...
# 578   François Létourneau             3
# 579           Anick Lemay             3
# 729             Sam Neill             3
# 727           Ethan Hawke             3
# 44           Keanu Reeves             3
#
# [100 rows x 2 columns]

# %%
actor_df[actor_df['actor'].str.contains(' ')].sort_values(by='movie_counts', ascending=False).head(100)
# Out:
#                     actor  movie_counts
# 1144         Rupert Grint            10
# 1143     Daniel Radcliffe            10
# 1145          Emma Watson             9
# 162     Samuel L. Jackson             8
# 541        Julianne Moore             7
# ...                   ...           ...
# 289       Keira Knightley             3
# 511   August Schellenberg             3
# 895             Joe Biden             3
# 698         Kevin Costner             3
# 1473          Lewis Black             3
#
# [100 rows x 2 columns]
